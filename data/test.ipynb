# %%
# !pip install streamlit
# Out:
# ...
#   Using cached cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# ...
#      ---------------------------------------- 0.0/44.3 kB ? eta -:--:--
#      ---------------------------------------- 44.3/44.3 kB 1.1 MB/s eta 0:00:00
# ...
#   Using cached jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# ...
#   Using cached referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# ...
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#     --------------------------------------- 0.2/9.1 MB 4.1 MB/s eta 0:00:03
#    -- ------------------------------------- 0.5/9.1 MB 6.8 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.1/9.1 MB 7.9 MB/s eta 0:00:02
#    ------- -------------------------------- 1.6/9.1 MB 9.3 MB/s eta 0:00:01
#    --------- ------------------------------ 2.3/9.1 MB 10.2 MB/s eta 0:00:01
#    ------------ --------------------------- 2.9/9.1 MB 10.7 MB/s eta 0:00:01
#    --------------- ------------------------ 3.5/9.1 MB 11.2 MB/s eta 0:00:01
# ...
